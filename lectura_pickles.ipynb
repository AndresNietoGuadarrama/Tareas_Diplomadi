# %% [markdown]
# # Lectura de archivos

# %% [markdown]
# Ejemplo de cómo puede leerse el archivo .pkl con gráficas

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import requests_html
import pickle
import numpy as np
import dill as pickl#Para no renombrar "pickles".
from requests_html import HTMLSession
from collections import defaultdict
from unidecode import unidecode
from datetime import datetime


filename="andres_nieto.pkl"

with open(filename, "rb") as f:
    datos=pickl.load(f)

    
'''
Graficacion:
'''
datos["figura_1"](datos["BANXICO"],datos["GRAFICAS"])
datos["figura_2"](datos["ANUAL"])
